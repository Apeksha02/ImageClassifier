# %% [markdown]
# <h2 style='color:dark blue' align='center'>Actors Image Classification<h2>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test_imgs/suriya1.jpg')
img.shape
# Out:
# (674, 674, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (674, 674)

# %%
gray
# Out:
# array([[226, 226, 226, ..., 226, 226, 226],
#        [226, 226, 226, ..., 226, 226, 226],
#        [226, 226, 226, ..., 226, 226, 226],
#        ...,
#        [226, 226, 226, ..., 226, 226, 226],
#        [226, 226, 226, ..., 226, 226, 226],
#        [226, 226, 226, ..., 226, 226, 226]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[221, 151, 245, 245]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (221, 151, 245, 245)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (245, 245, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_imgs/suriya1.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_imgs/suriya1.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_imgs/suriya2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_imgs/suriya2.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/akshay_kumar',
#  './dataset/allu_arjun',
#  './dataset/nani',
#  './dataset/srk',
#  './dataset/suriya']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".PNG"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# akshay_kumar
# Generating cropped images in folder:  ./dataset/cropped/akshay_kumar
# allu_arjun
# Generating cropped images in folder:  ./dataset/cropped/allu_arjun
# nani
# Generating cropped images in folder:  ./dataset/cropped/nani
# srk
# Generating cropped images in folder:  ./dataset/cropped/srk
# suriya
# Generating cropped images in folder:  ./dataset/cropped/suriya

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'akshay_kumar': ['./dataset/cropped/akshay_kumar\\akshay_kumar1.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar10.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar11.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar12.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar13.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar14.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar15.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar16.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar17.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar18.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar19.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar2.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar20.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar21.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar22.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar23.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar24.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar25.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar26.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar27.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar28.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar29.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar3.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar30.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar31.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar32.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar33.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar34.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar35.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar36.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar37.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar38.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar39.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar4.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar40.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar41.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar42.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar43.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar44.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar45.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar46.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar47.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar48.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar49.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar5.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar50.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar51.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar52.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar53.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar54.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar55.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar56.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar57.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar58.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar59.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar6.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar7.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar8.PNG',
#   './dataset/cropped/akshay_kumar\\akshay_kumar9.PNG'],
#  'allu_arjun': ['./dataset/cropped/allu_arjun\\allu_arjun1.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun10.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun11.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun12.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun13.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun14.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun15.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun16.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun17.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun18.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun19.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun2.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun20.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun21.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun22.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun23.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun24.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun25.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun26.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun27.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun28.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun29.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun3.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun30.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun31.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun32.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun33.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun34.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun35.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun36.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun37.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun38.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun39.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun4.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun40.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun41.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun42.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun43.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun44.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun45.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun46.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun47.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun48.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun49.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun5.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun50.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun51.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun52.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun53.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun54.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun55.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun56.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun6.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun7.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun8.PNG',
#   './dataset/cropped/allu_arjun\\allu_arjun9.PNG'],
#  'nani': ['./dataset/cropped/nani\\nani1.PNG',
#   './dataset/cropped/nani\\nani10.PNG',
#   './dataset/cropped/nani\\nani11.PNG',
#   './dataset/cropped/nani\\nani12.PNG',
#   './dataset/cropped/nani\\nani13.PNG',
#   './dataset/cropped/nani\\nani14.PNG',
#   './dataset/cropped/nani\\nani15.PNG',
#   './dataset/cropped/nani\\nani16.PNG',
#   './dataset/cropped/nani\\nani17.PNG',
#   './dataset/cropped/nani\\nani18.PNG',
#   './dataset/cropped/nani\\nani19.PNG',
#   './dataset/cropped/nani\\nani2.PNG',
#   './dataset/cropped/nani\\nani20.PNG',
#   './dataset/cropped/nani\\nani21.PNG',
#   './dataset/cropped/nani\\nani22.PNG',
#   './dataset/cropped/nani\\nani23.PNG',
#   './dataset/cropped/nani\\nani24.PNG',
#   './dataset/cropped/nani\\nani25.PNG',
#   './dataset/cropped/nani\\nani26.PNG',
#   './dataset/cropped/nani\\nani27.PNG',
#   './dataset/cropped/nani\\nani28.PNG',
#   './dataset/cropped/nani\\nani29.PNG',
#   './dataset/cropped/nani\\nani3.PNG',
#   './dataset/cropped/nani\\nani30.PNG',
#   './dataset/cropped/nani\\nani31.PNG',
#   './dataset/cropped/nani\\nani32.PNG',
#   './dataset/cropped/nani\\nani33.PNG',
#   './dataset/cropped/nani\\nani34.PNG',
#   './dataset/cropped/nani\\nani35.PNG',
#   './dataset/cropped/nani\\nani36.PNG',
#   './dataset/cropped/nani\\nani37.PNG',
#   './dataset/cropped/nani\\nani38.PNG',
#   './dataset/cropped/nani\\nani39.PNG',
#   './dataset/cropped/nani\\nani4.PNG',
#   './dataset/cropped/nani\\nani40.PNG',
#   './dataset/cropped/nani\\nani41.PNG',
#   './dataset/cropped/nani\\nani42.PNG',
#   './dataset/cropped/nani\\nani43.PNG',
#   './dataset/cropped/nani\\nani44.PNG',
#   './dataset/cropped/nani\\nani45.PNG',
#   './dataset/cropped/nani\\nani46.PNG',
#   './dataset/cropped/nani\\nani47.PNG',
#   './dataset/cropped/nani\\nani48.PNG',
#   './dataset/cropped/nani\\nani49.PNG',
#   './dataset/cropped/nani\\nani5.PNG',
#   './dataset/cropped/nani\\nani50.PNG',
#   './dataset/cropped/nani\\nani51.PNG',
#   './dataset/cropped/nani\\nani52.PNG',
#   './dataset/cropped/nani\\nani53.PNG',
#   './dataset/cropped/nani\\nani54.PNG',
#   './dataset/cropped/nani\\nani55.PNG',
#   './dataset/cropped/nani\\nani56.PNG',
#   './dataset/cropped/nani\\nani57.PNG',
#   './dataset/cropped/nani\\nani6.PNG',
#   './dataset/cropped/nani\\nani7.PNG',
#   './dataset/cropped/nani\\nani8.PNG',
#   './dataset/cropped/nani\\nani9.PNG'],
#  'srk': ['./dataset/cropped/srk\\srk1.PNG',
#   './dataset/cropped/srk\\srk10.PNG',
#   './dataset/cropped/srk\\srk11.PNG',
#   './dataset/cropped/srk\\srk12.PNG',
#   './dataset/cropped/srk\\srk13.PNG',
#   './dataset/cropped/srk\\srk14.PNG',
#   './dataset/cropped/srk\\srk15.PNG',
#   './dataset/cropped/srk\\srk16.PNG',
#   './dataset/cropped/srk\\srk17.PNG',
#   './dataset/cropped/srk\\srk18.PNG',
#   './dataset/cropped/srk\\srk19.PNG',
#   './dataset/cropped/srk\\srk2.PNG',
#   './dataset/cropped/srk\\srk20.PNG',
#   './dataset/cropped/srk\\srk21.PNG',
#   './dataset/cropped/srk\\srk22.PNG',
#   './dataset/cropped/srk\\srk23.PNG',
#   './dataset/cropped/srk\\srk24.PNG',
#   './dataset/cropped/srk\\srk25.PNG',
#   './dataset/cropped/srk\\srk26.PNG',
#   './dataset/cropped/srk\\srk27.PNG',
#   './dataset/cropped/srk\\srk28.PNG',
#   './dataset/cropped/srk\\srk29.PNG',
#   './dataset/cropped/srk\\srk3.PNG',
#   './dataset/cropped/srk\\srk30.PNG',
#   './dataset/cropped/srk\\srk31.PNG',
#   './dataset/cropped/srk\\srk32.PNG',
#   './dataset/cropped/srk\\srk33.PNG',
#   './dataset/cropped/srk\\srk34.PNG',
#   './dataset/cropped/srk\\srk35.PNG',
#   './dataset/cropped/srk\\srk36.PNG',
#   './dataset/cropped/srk\\srk37.PNG',
#   './dataset/cropped/srk\\srk38.PNG',
#   './dataset/cropped/srk\\srk39.PNG',
#   './dataset/cropped/srk\\srk4.PNG',
#   './dataset/cropped/srk\\srk40.PNG',
#   './dataset/cropped/srk\\srk41.PNG',
#   './dataset/cropped/srk\\srk42.PNG',
#   './dataset/cropped/srk\\srk43.PNG',
#   './dataset/cropped/srk\\srk44.PNG',
#   './dataset/cropped/srk\\srk45.PNG',
#   './dataset/cropped/srk\\srk46.PNG',
#   './dataset/cropped/srk\\srk47.PNG',
#   './dataset/cropped/srk\\srk48.PNG',
#   './dataset/cropped/srk\\srk49.PNG',
#   './dataset/cropped/srk\\srk5.PNG',
#   './dataset/cropped/srk\\srk50.PNG',
#   './dataset/cropped/srk\\srk51.PNG',
#   './dataset/cropped/srk\\srk52.PNG',
#   './dataset/cropped/srk\\srk53.PNG',
#   './dataset/cropped/srk\\srk54.PNG',
#   './dataset/cropped/srk\\srk55.PNG',
#   './dataset/cropped/srk\\srk56.PNG',
#   './dataset/cropped/srk\\srk6.PNG',
#   './dataset/cropped/srk\\srk7.PNG',
#   './dataset/cropped/srk\\srk8.PNG',
#   './dataset/cropped/srk\\srk9.PNG'],
#  'suriya': ['./dataset/cropped/suriya\\suriya1.PNG',
#   './dataset/cropped/suriya\\suriya10.PNG',
#   './dataset/cropped/suriya\\suriya11.PNG',
#   './dataset/cropped/suriya\\suriya12.PNG',
#   './dataset/cropped/suriya\\suriya13.PNG',
#   './dataset/cropped/suriya\\suriya14.PNG',
#   './dataset/cropped/suriya\\suriya15.PNG',
#   './dataset/cropped/suriya\\suriya16.PNG',
#   './dataset/cropped/suriya\\suriya17.PNG',
#   './dataset/cropped/suriya\\suriya18.PNG',
#   './dataset/cropped/suriya\\suriya19.PNG',
#   './dataset/cropped/suriya\\suriya2.PNG',
#   './dataset/cropped/suriya\\suriya20.PNG',
#   './dataset/cropped/suriya\\suriya21.PNG',
#   './dataset/cropped/suriya\\suriya22.PNG',
#   './dataset/cropped/suriya\\suriya23.PNG',
#   './dataset/cropped/suriya\\suriya24.PNG',
#   './dataset/cropped/suriya\\suriya25.PNG',
#   './dataset/cropped/suriya\\suriya26.PNG',
#   './dataset/cropped/suriya\\suriya27.PNG',
#   './dataset/cropped/suriya\\suriya28.PNG',
#   './dataset/cropped/suriya\\suriya29.PNG',
#   './dataset/cropped/suriya\\suriya3.PNG',
#   './dataset/cropped/suriya\\suriya30.PNG',
#   './dataset/cropped/suriya\\suriya31.PNG',
#   './dataset/cropped/suriya\\suriya32.PNG',
#   './dataset/cropped/suriya\\suriya33.PNG',
#   './dataset/cropped/suriya\\suriya34.PNG',
#   './dataset/cropped/suriya\\suriya35.PNG',
#   './dataset/cropped/suriya\\suriya36.PNG',
#   './dataset/cropped/suriya\\suriya37.PNG',
#   './dataset/cropped/suriya\\suriya38.PNG',
#   './dataset/cropped/suriya\\suriya39.PNG',
#   './dataset/cropped/suriya\\suriya4.PNG',
#   './dataset/cropped/suriya\\suriya40.PNG',
#   './dataset/cropped/suriya\\suriya41.PNG',
#   './dataset/cropped/suriya\\suriya42.PNG',
#   './dataset/cropped/suriya\\suriya43.PNG',
#   './dataset/cropped/suriya\\suriya44.PNG',
#   './dataset/cropped/suriya\\suriya45.PNG',
#   './dataset/cropped/suriya\\suriya46.PNG',
#   './dataset/cropped/suriya\\suriya47.PNG',
#   './dataset/cropped/suriya\\suriya48.PNG',
#   './dataset/cropped/suriya\\suriya49.PNG',
#   './dataset/cropped/suriya\\suriya5.PNG',
#   './dataset/cropped/suriya\\suriya50.PNG',
#   './dataset/cropped/suriya\\suriya51.PNG',
#   './dataset/cropped/suriya\\suriya52.PNG',
#   './dataset/cropped/suriya\\suriya53.PNG',
#   './dataset/cropped/suriya\\suriya54.PNG',
#   './dataset/cropped/suriya\\suriya55.PNG',
#   './dataset/cropped/suriya\\suriya56.PNG',
#   './dataset/cropped/suriya\\suriya57.PNG',
#   './dataset/cropped/suriya\\suriya58.PNG',
#   './dataset/cropped/suriya\\suriya59.PNG',
#   './dataset/cropped/suriya\\suriya6.PNG',
#   './dataset/cropped/suriya\\suriya60.PNG',
#   './dataset/cropped/suriya\\suriya61.PNG',
#   './dataset/cropped/suriya\\suriya62.PNG',
#   './dataset/cropped/suriya\\suriya63.PNG',
#   './dataset/cropped/suriya\\suriya64.PNG',
#   './dataset/cropped/suriya\\suriya65.PNG',
#   './dataset/cropped/suriya\\suriya66.PNG',
#   './dataset/cropped/suriya\\suriya67.PNG',
#   './dataset/cropped/suriya\\suriya68.PNG',
#   './dataset/cropped/suriya\\suriya69.PNG',
#   './dataset/cropped/suriya\\suriya7.PNG',
#   './dataset/cropped/suriya\\suriya70.PNG',
#   './dataset/cropped/suriya\\suriya71.PNG',
#   './dataset/cropped/suriya\\suriya72.PNG',
#   './dataset/cropped/suriya\\suriya73.PNG',
#   './dataset/cropped/suriya\\suriya74.PNG',
#   './dataset/cropped/suriya\\suriya75.PNG',
#   './dataset/cropped/suriya\\suriya76.PNG',
#   './dataset/cropped/suriya\\suriya77.PNG',
#   './dataset/cropped/suriya\\suriya78.PNG',
#   './dataset/cropped/suriya\\suriya79.PNG',
#   './dataset/cropped/suriya\\suriya8.PNG',
#   './dataset/cropped/suriya\\suriya80.PNG',
#   './dataset/cropped/suriya\\suriya81.PNG',
#   './dataset/cropped/suriya\\suriya82.PNG',
#   './dataset/cropped/suriya\\suriya83.PNG',
#   './dataset/cropped/suriya\\suriya9.PNG']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'akshay_kumar': 0, 'allu_arjun': 1, 'nani': 2, 'srk': 3, 'suriya': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[254],
#        [149],
#        [138],
#        ...,
#        [183],
#        [ 16],
#        [254]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (311, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7307692307692307

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77        14
#            1       0.73      0.50      0.59        16
#            2       0.67      0.67      0.67        15
#            3       0.91      0.83      0.87        12
#            4       0.66      0.90      0.76        21
#
#     accuracy                           0.73        78
#    macro avg       0.76      0.72      0.73        78
# weighted avg       0.74      0.73      0.73        78

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.781129
# 1        random_forest    0.553747
# 2  logistic_regression    0.750694
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                 {'logisticregression__C': 10}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=10, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7435897435897436

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6666666666666666

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8076923076923077

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[12,  1,  0,  1,  0],
#        [ 0, 10,  3,  1,  2],
#        [ 0,  3, 10,  1,  1],
#        [ 1,  0,  1,  9,  1],
#        [ 2,  0,  2,  0, 17]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'akshay_kumar': 0, 'allu_arjun': 1, 'nani': 2, 'srk': 3, 'suriya': 4}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\apubh\anaconda3\lib\site-packages (1.0.1)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
